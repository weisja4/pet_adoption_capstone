# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
import matplotlib.pyplot as plt

rdst = 815
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\weisj\anaconda3\envs\dsi\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
pets = pd.read_csv('../data/train/train.csv')

# %%
pets.head()
# Out:
#    Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 0     2       Nibble    3     299       0       1       1       7       0
# 1     2  No Name Yet    1     265       0       1       1       2       0
# 2     1       Brisco    1     307       0       1       2       7       0
# 3     1         Miko    4     307       0       2       1       2       0
# 4     1       Hunter    1     307       0       1       1       0       0
#
#    MaturitySize  ...  Health  Quantity  Fee  State  \
# 0             1  ...       1         1  100  41326
# 1             2  ...       1         1    0  41401
# 2             2  ...       1         1    0  41326
# 3             2  ...       1         1  150  41401
# 4             2  ...       1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  8480853f516546f6cf33aa88cd76c379         0
# 1  3082c7125d8fb66f7dd4bff4192c8b14         0
# 2  fa90fa5b1ee11c86938398b60abc32cb         0
# ...

# %%
X = pets.drop(columns = ('AdoptionSpeed'))
y = pets['AdoptionSpeed']

X_train, X_hold, y_train, y_hold  = train_test_split(X, y, test_size=0.25, random_state=rdst)

X_train, X_test, y_train, y_test  = train_test_split(X_train, y_train, test_size=0.25, random_state=rdst) # 0.25 x 0.8 = 0.2

print('Pets Shape: ', pets.shape)

print('X Train Shape: ' ,X_train.shape)

print('y Train Shape: ' ,y_train.shape)

print('X Test Shape: ', X_test.shape)
print('y Test Shape: ', y_test.shape)

print('X Holdout Shape: ', X_hold.shape)

print('y Holdout Shape: ', y_hold.shape)

X_hold
# Out:
# Pets Shape:  (14993, 24)
# X Train Shape:  (8433, 23)
# y Train Shape:  (8433,)
# X Test Shape:  (2811, 23)
# y Test Shape:  (2811,)
# X Holdout Shape:  (3749, 23)
# y Holdout Shape:  (3749,)
#        Type                                 Name  Age  Breed1  Breed2  Gender  \
# 216       1  3 Puppies -11wks Old Toilet Trained    2     307     141       3
# 1300      2                                  NaN    4     266       0       1
# 8031      2                      Timmy And Teena    3     299       0       3
# 4827      1                               Jaeger    3      26     307       1
# 1923      1               Mongrails For Adoption    1     307     307       3
# ...     ...                                  ...  ...     ...     ...     ...
# 6520      1                                   R9    1     307     307       1
# 2078      1                Rottweiler - Adoption    8     189       0       2
# 11782     1                            Sunshines    5     213     152       2
# ...

# %%
hold = pd.concat([X_hold, y_hold], axis = 1)

# %%
hold.to_csv('../data/holdout.csv', index = False)

# %%
train = pd.concat([X_train, y_train], axis = 1)
test = pd.concat([X_test, y_test], axis = 1)
pets = pd.concat([train,test], axis = 0)
# train.to_csv('../data/pets')

# %%
pets.shape
# Out:
# (11244, 24)

# %%
pets.head()
# Out:
#       Type            Name  Age  Breed1  Breed2  Gender  Color1  Color2  \
# 951      2          Brando   16     266       0       1       5       7
# 8331     2             Blu   48     266       0       2       5       7
# 954      1  Fara 2mths Old    2     307       0       2       2       0
# 3690     1      Summer Ooi   72     307       0       2       1       2
# 2572     1       Lucky Boy    1     307       0       1       1       2
#
#       Color3  MaturitySize  ...  Health  Quantity  Fee  State  \
# 951        0             2  ...       1         1  100  41326
# 8331       0             2  ...       1         1    0  41326
# 954        0             2  ...       1         1    0  41326
# 3690       7             2  ...       1         1    0  41327
# 2572       7             2  ...       1         1    0  41401
#
#                              RescuerID  VideoAmt  \
# 951   1470df093c280f9c9c90ccc2f8d44f27         0
# 8331  82a32b0880e7b35ae5133945a67e90a7         0
# ...

# %%
pets.to_csv('../data/pets.csv', index = False)

# %% [markdown]
# References:
# https://www.linkedin.com/pulse/kaggle-competition-multi-class-classification-image-alexandra/
# https://www.kaggle.com/c/petfinder-adoption-prediction/data
